# %% [markdown]
# <a href="https://colab.research.google.com/github/a109010028/computational-thinking-and-program-design/blob/main/%E3%80%8C%E7%A8%8B%E8%A8%AD%E6%9C%9F%E6%9C%AB_%E5%8B%95%E7%89%A9%E5%BF%83%E7%90%86%E6%B8%AC%E9%A9%97project%E3%80%8D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("超準！想知道你性格專屬的動物是什麼嗎？14個問題就能測出你的內心世界，趕快來一起試試吧！")
print("\n")
input("請輸入您的姓名:")
print("""問題列表:\n
1.你喜歡在一大堆人面前表達自己的意見嗎？\n
2.照團體照時，你一定會拚命擠到正中間的位置？\n
3.你害怕被人拒絕嗎？\n
4.比起與從未見過的人見面，你更喜歡再見已經見過的人？\n
5.比起在外面玩，你更喜歡獨自在家，享受自己的時間？\n 
6.你覺得和陌生人建立關係很困難？\n
7.和別人交談時，你的姿態通常是？\n
8.你覺得世界上最好聞的氣味是？\n
9.選一個屬於你家門牌引用的名言\n
10.你會選哪款圖案紙包禮物\n
11.以下令人討厭的事物中，你最受不了哪一項？\n
12.對於新的體驗或活動，我第一個關注的是？\n
13.你無聊的時候會做什麼？\n
14.你面對自己生活的各個方面的反應？\n
""")
q1="你喜歡在一大堆人面前表達自己的意見嗎？"
q2="照團體照時，你一定會拚命擠到正中間的位置？"
q3="你害怕被人拒絕嗎？"
q4="比起與從未見過的人見面，你更喜歡再見已經見過的人？"
q5="比起在外面玩，你更喜歡獨自在家，享受自己的時間？"
q6="你覺得和陌生人建立關係很困難？"
q7="和別人交談時，你的姿態通常是？"
q8="你覺得世界上最好聞的氣味是？"
q9="選一個屬於你家門牌引用的名言"
q10="你會選哪款圖案紙包禮物"
q11="以下令人討厭的事物中，你最受不了哪一項？"
q12="對於新的體驗或活動，我第一個關注的是？"
q13="你無聊的時候會做什麼？"
q14="你面對自己生活的各個方面的反應？"
A="""你的代表性動物是獅子、老虎。你在群體中屬於領導者，具有冒險且不認輸的精神，\n
對於表達自己的意見也非常有信心。個性活潑大方，不在意別人的眼光，勇敢實現自己的理想，\n
但是需要承受孤獨的壓力，因為可能會遭受到身邊的人不支持與不看好。\n
你的開朗也是一種保護色，害怕別人看到脆弱的自己，所以經常表現的坦然、開玩笑帶過自己的傷痛，但其實內心的你比誰都還渴望被人關心。
"""
B="""你的代表性動物是綿羊、兔子。你的個性溫和且敏銳，很會察言觀色。\n
你在人群中屬於不爭不搶，也不太會處理紛爭的類型。遇到委屈的事也不太表達出來，但一旦踩到你的底線，你會毫不留情的反擊！
"""
C="""你的代表性動物是熊。你的適應能力非常好，不管在什麼環境都能自如。\n
善於傾聽且跟身邊的人都處得很好，在朋友當中你是很好相處的，對於很多事不會強求，能泰然面對選擇、決定。\n
但因為太隨意沒脾氣，可能被有心人佔便宜，但你的個性是不會容忍欺善怕惡的。
"""
D="""獨居象徵動物是海龜、章魚。傾向獨居並不代表人際疏離，但會慎選往來的人，且擇善固執。\n
正如海龜慎選居住與生育地，不會因被打亂了原本居住的家園而輕易離開，也不會與垃圾和食物混在一起。\n
討厭任何小題大作帶來的壓力與困擾，否則你會像章魚自吃斷腳，你寧願進行有品質的一對一對談。
"""
print("\033[1;34m測驗開始!\033[0m")
print("\n")
ans1=input(f"問題一:\n{q1}\n是or否:")
if ans1=="是":
  print("\n")  
  print("問題二:")
  ans2=input(f"{q2}\n是or否:")
  if ans2=="是":
    print("\n")  
    print("問題六:")
    ans6=input(f"{q6}\n是or否:")
    print("\n")  
    print("問題七:")
    ans7=input(f"{q7}\n1.雙手緊握(輸入:一)\n2.觸碰與你交談的對象(輸入:二)\n您的作答:")
    if ans7=="一":
      print("\n")  
      print("問題九:")
      ans9=input(f"{q9}\n1.家是心靈所在(輸入:一)\n2.成家之道，日儉與勤(輸入:二)\n您的作答:")
      print("\n") 
      print("問題十:")
      ans10=input(f"{q10}\n:1.自己在手工紙上設計圖案(輸入:一)\n2.現成的圓點圖案紙(輸入:二)\n您的作答:")
      if ans10=="一":
        print("\n")  
        print("問題十二:")
        ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
        if ans12=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(B)
        elif ans12=="二":
          print("\n")
          print("問題十三:")
          ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
          if ans13=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(A)
          elif ans13=="二":
            print("\n")
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(C)
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      elif ans10=="二":
        print("\n")
        print("問題十一:")
        ans11=input(f"{q11}\n1.總是遲到的人(輸入:一)\n2.未經過你同意就吃你東西的人(輸入:二)\n您的作答:")
        if ans11=="一":
          print("\n")  
          print("問題十二:")
          ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          if ans12=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n") 
            print(B)
          elif ans12=="二":
            print("\n")
            print("問題十三:")
            ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
            if ans13=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n") 
              print(A)
            elif ans13=="二":
              print("\n")
              print("\033[1;33m即將生成!\033[0m")
              print("\n") 
              print(C)
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m!")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
        elif ans11=="二":
          print("\n")
          print("\033[1;33m即將生成!\033[0m")
          print("\n") 
          print(C)
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      else:
        print("\n")
        print("\033[1;31m請輸入題目要求之答案!\033[0m")
        print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    elif ans7=="二":
      print("\n")
      print("問題八:")
      ans8=input(f"{q8}\n1.剛岀爐的麵包(輸入:麵包)\n2.咖啡(輸入:咖啡)\n您的作答:")
      if ans8=="麵包":
        print("\n")  
        print("問題十二:")
        ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
        if ans12=="一":    
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n") 
          print(B)                 
        elif ans12=="二":
          print("\n")
          print("問題十三:")
          ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
          if ans13=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n") 
            print(A)
          elif ans13=="二":
            print("\n")
            print("\033[1;33m即將生成!\033[0m")
            print("\n") 
            print(C)
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次，\033[0m")   
      elif ans8=="咖啡":
        print("\n")
        print("問題十四:")
        ans14=input(f"{q14}\n1.井井有條，預先安排(輸入:一)\n2.喜歡突如其來，令人驚喜(輸入:二)\n您的作答:")
        if ans14=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n") 
          print(D)
        elif ans14=="二":
          print("\n") 
          print("問題十二:")
          ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          if ans12=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n") 
            print(B)
          elif ans12=="二":
            print("\n")
            print("問題十三:")
            ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
            if ans13=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n") 
              print(A)
            elif ans12=="二":
              print("\n")
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(C)
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    

      else:
        print("\n")
        print("\033[1;31m請輸入題目要求之答案!\033[0m")
        print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    else:
      print("\n")
      print("\033[1;31m請輸入題目要求之答案!\033[0m")
      print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
  elif ans2=="否":
    print("\n")
    print("問題四:")
    ans4=input(f"{q4}\n是or否:")
    if ans4=="是":
      print("\n")  
      print("問題五:")
      ans5=input(f"{q5}\n是or否:")
      if ans5=="是":
        print("\n")  
        print("問題六:")
        ans6=input(f"{q6}\n是or否:")
        print("\n")  
        print("問題七:")
        ans7=input(f"{q7}\n1.雙手緊握(輸入:一)\n2.觸碰與你交談的對象(輸入:二)\n您的作答:")
        if ans7=="一":
          print("\n")  
          print("問題九:")
          ans9=input(f"{q9}\n1.家是心靈所在(輸入:一)\n2.成家之道，日儉與勤(輸入:二)\n您的作答:")
          print("\n")  
          print("問題十:")
          ans10=input(f"{q10}\n:1.自己在手工紙上設計圖案(輸入:一)\n2.現成的圓點圖案紙(輸入:二)\n您的作答:")
          if ans10=="一":
            print("\n")  
            print("問題十二:")
            ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
            if ans12=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")  
              print(B)
            elif ans12=="二":
              print("\n")
              print("問題十三:")
              ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
              if ans13=="一": 
                print("\n")   
                print("\033[1;33m即將生成!\033[0m")
                print("\n") 
                print(A)
              elif ans13=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          elif ans10=="二":
              print("\n")
              print("問題十一:")
              ans11=input(f"{q11}\n1.總是遲到的人(輸入:一)\n2.未經過你同意就吃你東西的人(輸入:二)\n您的作答:")
              if ans11=="一":
                print("\n")  
                print("問題十二:")
                ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
                if ans12=="一":
                  print("\n")  
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")  
                  print(B)
                elif ans12=="二":
                  print("\n")
                  print("問題十三:")
                  ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
                  if ans13=="一":
                    print("\n")  
                    print("\033[1;33m即將生成!\033[0m")
                    print(A)
                  elif ans13=="二":
                    print("\n")
                    print("\033[1;33m即將生成!\033[0m")
                    print("\n")
                    print(C)
                  else:
                    print("\n")
                    print("\033[1;31m請輸入題目要求之答案!\033[0m")
                    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
                else:
                    print("\n")
                    print("\033[1;31m請輸入題目要求之答案!\033[0m")
                    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
              elif ans11=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        elif ans7=="二":
          print("\n")
          print("問題八:")
          ans8=input(f"{q8}\n1.剛岀爐的麵包(輸入:麵包)\n2.咖啡(輸入:咖啡)\n您的作答:")
          if ans8=="麵包":
            print("\n")  
            print("問題十二:")
            ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)2.它是否「有趣」(輸入二):")
          elif ans8=="咖啡":
            print("\n")
            print("問題十四:")
            ans14=input(f"{q14}\n1.井井有條，預先安排(輸入:一)\n2.喜歡突如其來，令人驚喜(輸入:二)\n您的作答:")
            if ans14=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(D)
            elif ans14=="二":
              print("\n") 
              print("問題十二")
              ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
              if ans12=="一":
                print("\n")  
                print("\033[1;33m即將生成!\033[0m!")
                print("\n")
                print(B)
              elif ans12=="二":
                print("\n")
                print("問題十三:")
                ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
                if ans13=="一":
                  print("\n")  
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(A)
                elif ans13=="二":
                  print("\n")
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(C)
                else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
              else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      elif ans5=="否":
        print("\n")  
        print("問題七:")
        ans7=input(f"{q7}\n1.雙手緊握(輸入:一)\n2.觸碰與你交談的對象(輸入:二)\n您的作答:")
        if ans7=="一":
          print("\n")  
          print("問題九:")
          ans9=input(f"{q9}\n1.家是心靈所在(輸入:一)\n2.成家之道，日儉與勤(輸入:二)\n您的作答:")
          print("\n")  
          print("問題十:")
          ans10=input(f"{q10}\n:1.自己在手工紙上設計圖案(輸入:一)\n2.現成的圓點圖案紙(輸入:二)\n您的作答:")
          if ans10=="一":
            print("\n")  
            print("問題十二:")
            ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
            if ans12=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")  
              print(B)
            elif ans12=="二":
              print("\n")
              print("問題十三:")
              ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
              if ans13=="一": 
                print("\n")   
                print("\033[1;33m即將生成!\033[0m")
                print("\n") 
                print(A)
              elif ans13=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m!")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          elif ans10=="二":
              print("\n")
              print("問題十一:")
              ans11=input(f"{q11}\n1.總是遲到的人(輸入:一)\n2.未經過你同意就吃你東西的人(輸入:二)\n您的作答:")
              if ans11=="一":
                print("\n")  
                print("問題十二:")
                ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
                if ans12=="一":
                  print("\n")  
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(B)
                elif ans12=="二":
                  print("\n")
                  print("問題十三:")
                  ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
                  if ans13=="一":
                    print("\n")  
                    print("\033[1;33m即將生成!\033[0m")
                    print("\n")
                    print(A)
                  elif ans13=="二":
                    print("\n")
                    print("\033[1;33m即將生成!\033[0m")
                    print("\n")
                    print(C)
                  else:
                    print("\n")
                    print("\033[1;31m請輸入題目要求之答案!\033[0m")
                    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
                else:
                    print("\n")
                    print("\033[1;31m請輸入題目要求之答案!\033[0m")
                    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
              elif ans11=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        elif ans7=="二":
          print("\n")
          print("問題八:")
          ans8=input(f"{q8}\n1.剛岀爐的麵包(輸入:麵包)\n2.咖啡(輸入:咖啡)\n您的作答:")
          if ans8=="麵包":
            print("\n")  
            print("問題十二:")
            ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          elif ans8=="咖啡":
            print("\n")
            print("問題十四:")
            ans14=input(f"{q14}\n1.井井有條，預先安排(輸入:一)\n2.喜歡突如其來，令人驚喜(輸入:二)\n您的作答:")
            if ans14=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(D)
            elif ans14=="二":
              print("\n") 
              print("問題十二:")
              ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
              if ans12=="一":
                print("\n")  
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(B)
              elif ans12=="二":
                print("\n")
                print("問題十三:")
                ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
                if ans13=="一":
                  print("\n")  
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n") 
                  print(A)
                elif ans13=="二":
                  print("\n")
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(C)
                else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
              else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    elif ans4=="否":
      print("\n")
      print("問題七:")
      ans7=input(f"{q7}\n1.雙手緊握(輸入:一)\n2.觸碰與你交談的對象(輸入:二)\n您的作答:")
      if ans7=="一":
          print("\n")  
          print("問題九:")
          ans9=input(f"{q9}\n1.家是心靈所在(輸入:一)\n2.成家之道，日儉與勤(輸入:二)\n您的作答:")
          print("\n")  
          print("問題十:")
          ans10=input(f"{q10}\n:1.自己在手工紙上設計圖案(輸入:一)\n2.現成的圓點圖案紙(輸入:二)\n您的作答:")
          if ans10=="一":
            print("\n")  
            print("問題十二:")
            ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
            if ans12=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")  
              print(B)
            elif ans12=="二":
              print("\n")
              print("問題十三:")
              ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
              if ans13=="一": 
                print("\n")   
                print("\033[1;33m即將生成!\033[0m")
                print("\n") 
                print(A)
              elif ans13=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m!")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          elif ans10=="二":
              print("\n")
              print("問題十一:")
              ans11=input(f"{q11}\n1.總是遲到的人(輸入:一)\n2.未經過你同意就吃你東西的人(輸入:二)\n您的作答:")
              if ans11=="一":
                print("\n")  
                print("問題十二:")
                ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
                if ans12=="一":
                  print("\n")  
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(B)
                elif ans12=="二":
                  print("\n")
                  print("問題十三:")
                  ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
                  if ans13=="一":
                    print("\n")  
                    print("\033[1;33m即將生成!\033[0m")
                    print("\n")
                    print(A)
                  elif ans13=="二":
                    print("\n")
                    print("\033[1;33m即將生成!\033[0m")
                    print("\n")
                    print(C)
                  else:
                    print("\n")
                    print("\033[1;31m請輸入題目要求之答案!\033[0m")
                    print("\033[1;31m請重新整理測驗，並從頭重新作答一次!\033[0m")
                else:
                    print("\n")
                    print("\033[1;31m請輸入題目要求之答案!\033[0m")
                    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
              elif ans11=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      elif ans7=="二":
          print("\n")
          print("問題八:")
          ans8=input(f"{q8}\n1.剛岀爐的麵包(輸入:麵包)\n2.咖啡(輸入:咖啡)\n您的作答:")
          if ans8=="麵包":
            print("\n")  
            print("問題十二:")
            ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
            if ans12=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(B)
            elif ans12=="二":
              print("\n")
              print("問題十三:")
              ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
              if ans13=="一":
                print("\n")  
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(A)
              elif ans13=="二":
                print("\n")
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(C)
              else:
                print("\n")
                print("\033[1;31m請輸入題目要求之答案!\033[0m")
                print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          elif ans8=="咖啡":
            print("\n")
            print("問題十四:")
            ans14=input(f"{q14}\n1.井井有條，預先安排(輸入:一)\n2.喜歡突如其來，令人驚喜(輸入:二)\n您的作答:")
            if ans14=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(D)
            elif ans14=="二":
              print("\n") 
              ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
              if ans12=="一":
                print("\n")  
                print("\033[1;33m即將生成!\033[0m")
                print("\n")
                print(B)
              elif ans12=="二":
                print("\n")
                print("問題十三:")
                ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
                if ans13=="一":
                  print("\n")  
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(A)
                elif ans13=="二":
                  print("\n")
                  print("\033[1;33m即將生成!\033[0m")
                  print("\n")
                  print(C)
                else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
              else:
                  print("\n")
                  print("\033[1;31m請輸入題目要求之答案!\033[0m")
                  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m!")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    else:
      print("\n")
      print("\033[1;31m請輸入題目要求之答案!\033[0m!")
      print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
  else:
    print("\n")
    print("\033[1;31m請輸入題目要求之答案!\033[0m")
    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
elif ans1=="否":
  print("\n")
  print("問題三:")
  ans3=input(f"{q3}\n是or否:")
  if ans3=="是":
    print("\n")  
    print("問題六:")
    ans6=input(f"{q6}\n是or否:")
    print("\n")  
    print("問題七:")
    ans7=input(f"{q7}\n1.雙手緊握(輸入:一)\n2.觸碰與你交談的對象(輸入:二)\n您的作答:")
    if ans7=="一":
      print("\n")  
      print("問題九:")
      ans9=input(f"{q9}\n1.家是心靈所在(輸入:一)\n2.成家之道，日儉與勤(輸入:二)\n您的作答:")
      print("\n")  
      print("問題十:")
      ans10=input(f"{q10}\n:1.自己在手工紙上設計圖案(輸入:一)\n2.現成的圓點圖案紙(輸入:二)\n您的作答:")
      if ans10=="一":
        print("\n")  
        print("問題十二:")
        ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
        if ans12=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(B)
        elif ans12=="二":
          print("\n")
          print("問題十三:")
          ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
          if ans13=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(A)
          elif ans13=="二":
            print("\n")
            print("\033[1;33m即將生成!\033[0m")
            print("\n")  
            print(C)
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      elif ans10=="二":
        print("\n")
        print("問題十一:")
        ans11=input(f"{q11}\n1.總是遲到的人(輸入:一)\n2.未經過你同意就吃你東西的人(輸入:二)\n您的作答:")
        if ans11=="一":
          print("\n")  
          print("問題十二:")
          ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          if ans12=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(B)
          elif ans12=="二":
            print("\n")
            print("問題十三:")
            ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
            if ans13=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(A)
            elif ans13=="二":
              print("\n")
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(C)
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
        elif ans11=="二":
          print("\n")
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(C)
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      else:
        print("\n")
        print("\033[1;31m請輸入題目要求之答案!\033[0m")
        print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m") 
    elif ans7=="二":
      print("\n")
      print("問題八:")
      ans8=input(f"{q8}\n1.剛岀爐的麵包(輸入:麵包)\n2.咖啡(輸入:咖啡)\n您的作答:")
      if ans8=="麵包":
        print("\n")  
        print("問題十二:")
        ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
      elif ans8=="咖啡":
        print("\n")
        print("問題十四:")
        ans14=input(f"{q14}\n1.井井有條，預先安排(輸入:一)\n2.喜歡突如其來，令人驚喜(輸入:二)\n您的作答:")
        if ans14=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(D)
        elif ans14=="二":
          print("\n") 
          ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          if ans12=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(B)
          elif ans12=="二":
            print("\n")
            print("問題十三:")
            ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
            if ans13=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(A)
            elif ans13=="二":
              print("\n")
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(C)
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    

      else:
        print("\n")
        print("\033[1;31m請輸入題目要求之答案!\033[0m")
        print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    else:
      print("\n")
      print("\033[1;31m請輸入題目要求之答案!\033[0m")
      print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
  elif ans3=="否":
    print("\n")  
    print("問題七:")
    ans7=input(f"{q7}\n1.雙手緊握(輸入:一)\n2.觸碰與你交談的對象(輸入:二)\n您的作答:")
    if ans7=="一":
      print("\n")  
      print("問題九:")
      ans9=input(f"{q9}\n1.家是心靈所在(輸入:一)\n2.成家之道，日儉與勤(輸入:二)\n您的作答:")
      print("\n")  
      print("問題十:")
      ans10=input(f"{q10}\n:1.自己在手工紙上設計圖案(輸入:一)\n2.現成的圓點圖案紙(輸入:二)\n您的作答:")
      if ans10=="一":
        print("\n")  
        print("問題十二:")
        ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
        if ans12=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(B)
        elif ans12=="二":
          print("\n")
          print("問題十三:")
          ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
          if ans13=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(A)
          elif ans13=="二":
            print("\n")
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(C)
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      elif ans10=="二":
        print("\n")
        print("問題十一:")
        ans11=input(f"{q11}\n1.總是遲到的人(輸入:一)\n2.未經過你同意就吃你東西的人(輸入:二)\n您的作答:")
        if ans11=="一":
          print("\n")  
          print("問題十二:")
          ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          if ans12=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(B)
          elif ans12=="二":
            print("\n")
            print("問題十三:")
            ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
            if ans13=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(A)
            elif ans13=="二":
              print("\n")
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(C)
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
        elif ans11=="二":
          print("\n")
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(C)
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      else:
        print("\n")
        print("\033[1;31m請輸入題目要求之答案!\033[0m")
        print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    elif ans7=="二":
      print("\n")
      print("問題八:")
      ans8=input(f"{q8}\n1.剛岀爐的麵包(輸入:麵包)\n2.咖啡(輸入:咖啡)\n您的作答:")
      if ans8=="麵包":
        print("\n")  
        print("問題十二:")
        ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
        if ans12=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(B)
        elif ans12=="二":
          print("\n")
          print("問題十三:")
          ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
          if ans13=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(A)
          elif ans13=="二":
            print("\n")
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(C)
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
      elif ans8=="咖啡":
        print("\n")
        print("問題十四:")
        ans14=input(f"{q14}\n1.井井有條，預先安排(輸入:一)\n2.喜歡突如其來，令人驚喜(輸入:二)\n您的作答:")
        if ans14=="一":
          print("\n")  
          print("\033[1;33m即將生成!\033[0m")
          print("\n")
          print(D)
        elif ans14=="二":
          print("\n")
          print("問題十二:") 
          ans12=input(f"{q12}\n1.它是否「有用」(輸入:一)\n2.它是否「有趣」(輸入:二)\n您的作答:")
          if ans12=="一":
            print("\n")  
            print("\033[1;33m即將生成!\033[0m")
            print("\n")
            print(B)
          elif ans12=="二":
            print("\n")
            print("問題十三:")
            ans13=input(f"{q13}\n1.你會出門找樂子(輸入:一)\n2.你寧願呆在家裡讀一本好書或看電視(輸入:二)\n您的作答:")
            if ans13=="一":
              print("\n")  
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(A)
            elif ans13=="二":
              print("\n")
              print("\033[1;33m即將生成!\033[0m")
              print("\n")
              print(C)
            else:
              print("\n")
              print("\033[1;31m請輸入題目要求之答案!\033[0m")
              print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
          else:
            print("\n")
            print("\033[1;31m請輸入題目要求之答案!\033[0m")
            print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")    
        else:
          print("\n")
          print("\033[1;31m請輸入題目要求之答案!\033[0m")
          print("\033[1;31m請重新整理測驗，並從頭重新作答一次\033[0m。")    

      else:
        print("\n")
        print("\033[1;31m請輸入題目要求之答案!\033[0m")
        print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
    else:
      print("\n")
      print("\033[1;31m請輸入題目要求之答案!\033[0m")
      print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")

  else:
    print("\n")
    print("\033[1;31m請輸入題目要求之答案!\033[0m")
    print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
else:
  print("\n")
  print("\033[1;31m請輸入題目要求之答案!\033[0m")
  print("\033[1;31m請重新整理測驗，並從頭重新作答一次。\033[0m")
# Out:
# 超準！想知道你性格專屬的動物是什麼嗎？14個問題就能測出你的內心世界，趕快來一起試試吧！
#
#
# 請輸入您的姓名:次]]
# 問題列表:
#
# 1.你喜歡在一大堆人面前表達自己的意見嗎？
#
# 2.照團體照時，你一定會拚命擠到正中間的位置？
#
# 3.你害怕被人拒絕嗎？
#
# 4.比起與從未見過的人見面，你更喜歡再見已經見過的人？
#
# 5.比起在外面玩，你更喜歡獨自在家，享受自己的時間？
#
# 6.你覺得和陌生人建立關係很困難？
#
# 7.和別人交談時，你的姿態通常是？
#
# 8.你覺得世界上最好聞的氣味是？
#
# 9.選一個屬於你家門牌引用的名言
#
# 10.你會選哪款圖案紙包禮物
#
# 11.以下令人討厭的事物中，你最受不了哪一項？
#
# 12.對於新的體驗或活動，我第一個關注的是？
#
# 13.你無聊的時候會做什麼？
#
# 14.你面對自己生活的各個方面的反應？
#
#
# 測驗開始!
#
#
# 問題一:
# 你喜歡在一大堆人面前表達自己的意見嗎？
# 是or否:是
#
#
# 問題二:
# 照團體照時，你一定會拚命擠到正中間的位置？
# 是or否:是
#
#
# 問題六:
# 你覺得和陌生人建立關係很困難？
# 是or否:是
#
#
# 問題七:
# 和別人交談時，你的姿態通常是？
# 1.雙手緊握(輸入:一)
# 2.觸碰與你交談的對象(輸入:二)
# 您的作答:一
#
#
# 問題九:
# 選一個屬於你家門牌引用的名言
# 1.家是心靈所在(輸入:一)
# 2.成家之道，日儉與勤(輸入:二)
# 您的作答:一
#
#
# 問題十:
# 你會選哪款圖案紙包禮物
# :1.自己在手工紙上設計圖案(輸入:一)
# 2.現成的圓點圖案紙(輸入:二)
# 您的作答:一
#
#
# 問題十二:
# 對於新的體驗或活動，我第一個關注的是？
# 1.它是否「有用」(輸入:一)
# 2.它是否「有趣」(輸入:二)
# 您的作答:二
#
#
# 問題十三:
# 你無聊的時候會做什麼？
# 1.你會出門找樂子(輸入:一)
# 2.你寧願呆在家裡讀一本好書或看電視(輸入:二)
# 您的作答:二
#
#
# 即將生成!
#
#
# 你的代表性動物是熊。你的適應能力非常好，不管在什麼環境都能自如。
#
# ...

# %% [markdown]
# 導文
# 超準！想知道你性格專屬的動物是什麼嗎？15個問題就能測出你的內心，趕快來一起試試吧！
#
# 問題
# 1.你喜歡在一大堆人面前表達自己的意見嗎？
# 喜歡 →2
# 不喜歡 →3
#
# 2.照團體照時，你一定會拚命擠到正中間的位置？
# 會 →6
# 不會→4
#
# 3.你害怕被人拒絕嗎
# 是→6
# 不是→7
#
# 4.比起與從未見過的人見面，你更喜歡再見已經見過的人？
# 是→5
# 不是→7
#
# 5.比起在外面玩，你更喜歡獨自在家，享受自己的時間？
# 是→6
# 不是→7
#
# 6.你覺得和陌生人建立關係很困難？
# 是→7
# 不是→7
#
# 7.和別人交談時，你的姿態通常是？
# 雙手緊握→9
# 觸碰與你交談的對象→8
#
# 8.你覺得世界上最好聞的氣味是？
# 剛岀爐的麵包→12
# 咖啡→14
#
# 9.選一個屬於你家門牌引用的名言
# 家是心靈所在→10
# 成家之道，日儉與勤→10
#
# 10.你會選哪款圖案紙包禮物
# 自己在手工紙上設計圖案→12
# 現成的圓點圖案紙→11
#
#
# 11.以下令人討厭的事物中，你最受不了哪一項
# 總是遲到的人→12
# 未經過你同意就吃你東西的人→C
#
# 12.對於新的體驗或活動，我第一個關注的是？
# 它是否「有用」?→B
# 它是否「有趣」?→13
#
# 13.你無聊的時候會做什麼？
# 你會出門找樂子→A
# 你寧願呆在家裡讀一本好書或看電視→C
#
# 14.你面對自己生活的各個方面的反應
# 井井有條，預先安排→D
# 喜歡突如其來，令人驚喜→12
#
#
# 人格類型
#
# A:你的代表性動物是獅子、老虎。你在群體中屬於領導者，具有冒險且不認輸的精神，對於表達自己的意見也非常有信心。個性活潑大方，不在意別人的眼光，勇敢實現自己的理想，但是需要承受孤獨的壓力，因為可能會遭受到身邊的人不支持與不看好。你的開朗也是一種保護色，害怕別人看到脆弱的自己，所以經常表現的坦然、開玩笑帶過自己的傷痛，但其實內心的你比誰都還渴望被人關心。
#
# B:你的代表性動物是綿羊、兔子。你的個性溫和且敏銳，很會察言觀色。你在人群中屬於不爭不搶，也不太會處理紛爭的類型。遇到委屈的事也不太表達出來，但一旦踩到你的底線，你會毫不留情的反擊！
#
# C:你的代表性動物是熊。你的適應能力非常好，不管在什麼環境都能自如。善於傾聽且跟身邊的人都處得很好，在朋友當中你是很好相處的，對於很多事不會強求，能泰然面對選擇、決定。但因為太隨意沒脾氣，可能被有心人佔便宜，但你的個性是不會容忍欺善怕惡的。
#
# D：獨居象徵動物是海龜、章魚。傾向獨居並不代表人際疏離，但會慎選往來的人，且擇善固執。正如海龜慎選居住與生育地，不會因被打亂了原本居住的家園而輕易離開，也不會與垃圾和食物混在一起。討厭任何小題大作帶來的壓力與困擾，否則你會像章魚自吃斷腳，你寧願進行有品質的一對一對談。
#
# 設計理念：網路上有很多類似這種多題式心理測驗，但常常需要跳來跳去，一不小心就會搞混，我們利用程式中能下決策的功能，做出一個只要輸入答案就會接續相對應的心理問題的程式，解決那些總是做題做到最後，不知道應該跳到哪題的人的困擾；再者，程式有互動性，比起只是白紙上一連串的問題，冷冰冰的文字沒有溫度，利用一來一往的互動，希望讓使用者更能感受到樂趣；最後，我們在測驗開始之前，先給使用者看過所有題目，這樣更能增加刺激感，因為使用者不知道自己哪些題目會回答到，哪些不會。
#
# 同組人員：李思琪　楊曉林　陳宣樺　楊怡萱
